# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
with open("/Users/lamprad/Downloads/final_project/600entity.txt", "r") as f:
    result = []
    for j in f.readlines():
        result.append([j.split()[0], j.split()[-1], j.split()[-3], j.split()[-2]])
    result = pd.DataFrame(result[1::], columns=result[0])
    categories = set(result["calss"].values)

with open("/Users/lamprad/Downloads/final_project/original_600.txt", "r") as f:
    data = [sentences[:-1] for sentences in f.readlines()]
    data.pop(-1)

# %%
data_len = [d.__len__() for d in data]

sns.kdeplot(data_len)
